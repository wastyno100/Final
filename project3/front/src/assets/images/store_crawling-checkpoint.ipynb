# %% [markdown]
# ### 변수명 정의
# - driver : 웹(크롬)
# - mall_click : 좌측 쇼핑몰 탭
# - best_click : 베스트 상품(상단 베스트상품 탭은 내용이 계속 변경됨....)
# - name : 상품내용
# - num : 번호
# - price : 가격
# - star : 별점
# - data_list : 데이터 리스트
# - best_df : 데이터 프레임

# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import pandas as pd
import re
import urllib.request
import urllib
import schedule

# %%
#드라이버 지정=크롬
driver=webdriver.Chrome()

#자동실행

#목표 홈페이지 열기
driver.get("https://tpirates.com/") #홈페이지 열기
time.sleep(5) #로딩시간 5초(에러발생시 시간 늘려서 재실행해보기)

#시세 클릭
mall_click = driver.find_elements("css selector","#wrap > div.sc-eBMEME.cXOJzI > div.search-form > div.sc-dhKdcB.sc-cWSHoV.fsycso.dqpzTc >div:nth-child(3) > a")[0]
mall_click.click() #클릭
time.sleep(3) #로딩시간 3초(에러발생시 시간 늘려서 재실행해보기)

# %%
from time import localtime
from time import strftime
from time import time
data_list = []

for i in range(1, 200):
   
    # 10의 배수인 경우 스크롤 내리고 10초 대기
    if i % 10 == 1 and i > 1:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")  
        driver.implicitly_wait(10)
        #print('inner if')
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
    
    try:
        num=i
        
        # 상품명
        name = soup.select(f"ul.sc-xwuxA.isTdUO > li:nth-child({i}) > div > div >div.sc-eeDRCY.kPzmFC")[0].text

        # 가격
        extracted_number = soup.select(f"ul.sc-xwuxA.isTdUO > li:nth-child({i}) > div > div >div.sc-eeDRCY.cMAA-Df")[0].text

        # 숫자변환 정규표현식
        formatted_number = re.sub(r'[^\d]', '', extracted_number)
        price = int(formatted_number)



        tm = time()
        today = localtime(tm)
        day = strftime('%Y-%m-%d', today)
        data_list.append([num,name,price,day])        
        #print("inner try")
        
    except Exception as e:
        pass

# %%
print(data_list)
len(data_list)
# Out:
# [[1, '광어', 25000, '2024-03-22'], [2, '우럭', 25000, '2024-03-22'], [3, '참돔', 25000, '2024-03-22'], [4, '연어', 5000, '2024-03-22'], [5, '돌돔', 70000, '2024-03-22'], [6, '감성돔', 45000, '2024-03-22'], [7, '쥐돔', 60000, '2024-03-22'], [8, '강담돔', 100000, '2024-03-22'], [9, '동갈돗돔', 50000, '2024-03-22'], [10, '벵에돔', 50000, '2024-03-22'], [11, '장대', 25000, '2024-03-22'], [12, '긴꼬리벵에돔', 50000, '2024-03-22'], [13, '방어', 30000, '2024-03-22'], [14, '잿방어', 50000, '2024-03-22'], [15, '혹돔', 50000, '2024-03-22'], [16, '쥐노래미', 25000, '2024-03-22'], [17, '농어', 25000, '2024-03-22'], [18, '라운드폼파노', 60000, '2024-03-22'], [19, '가숭어', 25000, '2024-03-22'], [20, '보리숭어', 15000, '2024-03-22'], [21, '바다송어', 10000, '2024-03-22'], [22, '강도다리', 25000, '2024-03-22'], [23, '돌가자미', 30000, '2024-03-22'], [24, '줄가자미', 50000, '2024-03-22'], [25, '도다리', 50000, '2024-03-22'], [26, '문치가자미', 25000, '2024-03-22'], [27, '참가자미', 25000, '2024-03-22'], [28, '홍가자미', 6670, '2024-03-22'], [29, '범가자미', 40000, '2024-03-22'], [30, '찰가자미', 70000, '2024-03-22'], [31, '기름가자미', 80000, '2024-03-22'], [32, '물가자미', 1000, '2024-03-22'], [33, '도치', 25000, '2024-03-22'], [34, '전어', 2000, '2024-03-22'], [35, '쥐치', 35000, '2024-03-22'], [36, '말쥐치', 30000, '2024-03-22'], [37, '청어', 2500, '2024-03-22'], [38, '줄무늬전갱이', 50000, '2024-03-22'], [39, '고등어', 5000, '2024-03-22'], [40, '부시리', 25000, '2024-03-22'], [41, '능성어', 59000, '2024-03-22'], [42, '붉바리', 200000, '2024-03-22'], [43, '자바리', 150000, '2024-03-22'], [44, '대왕자바리', 55000, '2024-03-22'], [45, '참복', 60000, '2024-03-22'], [46, '밀복', 50000, '2024-03-22'], [47, '황금광어', 45000, '2024-03-22'], [48, '터봇', 40000, '2024-03-22'], [49, '황새치', 40000, '2024-03-22'], [50, '참다랑어', 60000, '2024-03-22'], [51, '눈다랑어', 30000, '2024-03-22'], [52, '개상어', 5000, '2024-03-22'], [53, '가오리', 20000, '2024-03-22'], [54, '양미리', 350, '2024-03-22'], [55, '실치', 25000, '2024-03-22'], [56, '괴도라치', 60000, '2024-03-22'], [57, '등가시치', 30000, '2024-03-22'], [58, '벤자리', 70000, '2024-03-22'], [59, '볼락', 35000, '2024-03-22'], [60, '삼세기', 35000, '2024-03-22'], [61, '쏨뱅이', 35000, '2024-03-22'], [62, '용치놀래기', 35000, '2024-03-22'], [63, '열기', 50000, '2024-03-22'], [64, '장갱이', 60000, '2024-03-22'], [65, '빨간횟대', 30000, '2024-03-22'], [66, '붕장어', 25000, '2024-03-22'], [67, '먹장어', 40000, '2024-03-22'], [68, '민물장어', 40000, '2024-03-22'], [69, '메기', 12000, '2024-03-22'], [70, '자라', 28000, '2024-03-22'], [71, '가물치', 17000, '2024-03-22'], [72, '잉어', 8000, '2024-03-22'], [73, '참붕어', 9000, '2024-03-22'], [74, '벌레문치', 60000, '2024-03-22'], [75, '망둥어', 10000, '2024-03-22'], [76, '아홉동가리', 35000, '2024-03-22'], [77, '점성어', 24000, '2024-03-22'], [78, '민어', 20000, '2024-03-22'], [79, '큰민어', 35000, '2024-03-22'], [80, '물메기', 10000, '2024-03-22'], [81, '자리돔', 12000, '2024-03-22'], [82, '임연수어', 3340, '2024-03-22'], [83, '성대', 25000, '2024-03-22'], [84, '호박돔', 35000, '2024-03-22'], [85, '블루 킹크랩', 85000, '2024-03-22'], [86, '레드 킹크랩', 70000, '2024-03-22'], [87, '브라운 킹크랩', 60000, '2024-03-22'], [88, '던지니스크랩', 60000, '2024-03-22'], [89, '대게', 35000, '2024-03-22'], [90, '홍게', 30000, '2024-03-22'], [91, '타이탄 홍게', 50000, '2024-03-22'], [92, '랍스터', 60000, '2024-03-22'], [93, '왕밤송이게', 70000, '2024-03-22'], [94, '깨다시꽃게', 25000, '2024-03-22'], [95, '수꽃게', 15000, '2024-03-22'], [96, '암꽃게', 25000, '2024-03-22'], [97, '돌게', 15000, '2024-03-22'], [98, '참게', 21000, '2024-03-22'], [99, '절단꽃게', 25000, '2024-03-22'], [100, '소라게발', 19000, '2024-03-22'], [101, '생새우', 23000, '2024-03-22'], [102, '민물새우', 40000, '2024-03-22'], [103, '흰다리새우', 30000, '2024-03-22'], [104, '단새우', 10000, '2024-03-22'], [105, '블랙타이거새우', 30000, '2024-03-22'], [106, '타이거새우', 50000, '2024-03-22'], [107, '씨타이거', 40000, '2024-03-22'], [108, '홍새우', 20000, '2024-03-22'], [109, '대하', 35000, '2024-03-22'], [110, '보리새우', 7000, '2024-03-22'], [111, '도화새우', 200000, '2024-03-22'], [112, '닭새우', 200000, '2024-03-22'], [113, '꽃새우', 16000, '2024-03-22'], [114, '딱새우', 10000, '2024-03-22'], [115, '문어', 35000, '2024-03-22'], [116, '새우살', 16000, '2024-03-22'], [117, '칵테일새우 ...
# 199

# %%
print(data_list)
# Out:
# [[1, '광어', 25000, '2024-03-22'], [2, '우럭', 25000, '2024-03-22'], [3, '참돔', 25000, '2024-03-22'], [4, '연어', 5000, '2024-03-22'], [5, '돌돔', 70000, '2024-03-22'], [6, '감성돔', 45000, '2024-03-22'], [7, '쥐돔', 60000, '2024-03-22'], [8, '강담돔', 100000, '2024-03-22'], [9, '동갈돗돔', 50000, '2024-03-22'], [10, '벵에돔', 50000, '2024-03-22'], [11, '장대', 25000, '2024-03-22'], [12, '긴꼬리벵에돔', 50000, '2024-03-22'], [13, '방어', 30000, '2024-03-22'], [14, '잿방어', 50000, '2024-03-22'], [15, '혹돔', 50000, '2024-03-22'], [16, '쥐노래미', 25000, '2024-03-22'], [17, '농어', 25000, '2024-03-22'], [18, '라운드폼파노', 60000, '2024-03-22'], [19, '가숭어', 25000, '2024-03-22'], [20, '보리숭어', 15000, '2024-03-22'], [21, '바다송어', 10000, '2024-03-22'], [22, '강도다리', 25000, '2024-03-22'], [23, '돌가자미', 30000, '2024-03-22'], [24, '줄가자미', 50000, '2024-03-22'], [25, '도다리', 50000, '2024-03-22'], [26, '문치가자미', 25000, '2024-03-22'], [27, '참가자미', 25000, '2024-03-22'], [28, '홍가자미', 6670, '2024-03-22'], [29, '범가자미', 40000, '2024-03-22'], [30, '찰가자미', 70000, '2024-03-22'], [31, '기름가자미', 80000, '2024-03-22'], [32, '물가자미', 1000, '2024-03-22'], [33, '도치', 25000, '2024-03-22'], [34, '전어', 2000, '2024-03-22'], [35, '쥐치', 35000, '2024-03-22'], [36, '말쥐치', 30000, '2024-03-22'], [37, '청어', 2500, '2024-03-22'], [38, '줄무늬전갱이', 50000, '2024-03-22'], [39, '고등어', 5000, '2024-03-22'], [40, '부시리', 25000, '2024-03-22'], [41, '능성어', 59000, '2024-03-22'], [42, '붉바리', 200000, '2024-03-22'], [43, '자바리', 150000, '2024-03-22'], [44, '대왕자바리', 55000, '2024-03-22'], [45, '참복', 60000, '2024-03-22'], [46, '밀복', 50000, '2024-03-22'], [47, '황금광어', 45000, '2024-03-22'], [48, '터봇', 40000, '2024-03-22'], [49, '황새치', 40000, '2024-03-22'], [50, '참다랑어', 60000, '2024-03-22'], [51, '눈다랑어', 30000, '2024-03-22'], [52, '개상어', 5000, '2024-03-22'], [53, '가오리', 20000, '2024-03-22'], [54, '양미리', 350, '2024-03-22'], [55, '실치', 25000, '2024-03-22'], [56, '괴도라치', 60000, '2024-03-22'], [57, '등가시치', 30000, '2024-03-22'], [58, '벤자리', 70000, '2024-03-22'], [59, '볼락', 35000, '2024-03-22'], [60, '삼세기', 35000, '2024-03-22'], [61, '쏨뱅이', 35000, '2024-03-22'], [62, '용치놀래기', 35000, '2024-03-22'], [63, '열기', 50000, '2024-03-22'], [64, '장갱이', 60000, '2024-03-22'], [65, '빨간횟대', 30000, '2024-03-22'], [66, '붕장어', 25000, '2024-03-22'], [67, '먹장어', 40000, '2024-03-22'], [68, '민물장어', 40000, '2024-03-22'], [69, '메기', 12000, '2024-03-22'], [70, '자라', 28000, '2024-03-22'], [71, '가물치', 17000, '2024-03-22'], [72, '잉어', 8000, '2024-03-22'], [73, '참붕어', 9000, '2024-03-22'], [74, '벌레문치', 60000, '2024-03-22'], [75, '망둥어', 10000, '2024-03-22'], [76, '아홉동가리', 35000, '2024-03-22'], [77, '점성어', 24000, '2024-03-22'], [78, '민어', 20000, '2024-03-22'], [79, '큰민어', 35000, '2024-03-22'], [80, '물메기', 10000, '2024-03-22'], [81, '자리돔', 12000, '2024-03-22'], [82, '임연수어', 3340, '2024-03-22'], [83, '성대', 25000, '2024-03-22'], [84, '호박돔', 35000, '2024-03-22'], [85, '블루 킹크랩', 85000, '2024-03-22'], [86, '레드 킹크랩', 70000, '2024-03-22'], [87, '브라운 킹크랩', 60000, '2024-03-22'], [88, '던지니스크랩', 60000, '2024-03-22'], [89, '대게', 35000, '2024-03-22'], [90, '홍게', 30000, '2024-03-22'], [91, '타이탄 홍게', 50000, '2024-03-22'], [92, '랍스터', 60000, '2024-03-22'], [93, '왕밤송이게', 70000, '2024-03-22'], [94, '깨다시꽃게', 25000, '2024-03-22'], [95, '수꽃게', 15000, '2024-03-22'], [96, '암꽃게', 25000, '2024-03-22'], [97, '돌게', 15000, '2024-03-22'], [98, '참게', 21000, '2024-03-22'], [99, '절단꽃게', 25000, '2024-03-22'], [100, '소라게발', 19000, '2024-03-22'], [101, '생새우', 23000, '2024-03-22'], [102, '민물새우', 40000, '2024-03-22'], [103, '흰다리새우', 30000, '2024-03-22'], [104, '단새우', 10000, '2024-03-22'], [105, '블랙타이거새우', 30000, '2024-03-22'], [106, '타이거새우', 50000, '2024-03-22'], [107, '씨타이거', 40000, '2024-03-22'], [108, '홍새우', 20000, '2024-03-22'], [109, '대하', 35000, '2024-03-22'], [110, '보리새우', 7000, '2024-03-22'], [111, '도화새우', 200000, '2024-03-22'], [112, '닭새우', 200000, '2024-03-22'], [113, '꽃새우', 16000, '2024-03-22'], [114, '딱새우', 10000, '2024-03-22'], [115, '문어', 35000, '2024-03-22'], [116, '새우살', 16000, '2024-03-22'], [117, '칵테일새우 ...

# %%
import MySQLdb

conn = MySQLdb.connect(
    user="root",
    passwd="1234",
    host="43.200.44.210",
    db="seastore"
    # charset="utf-8"
)
print(type(conn))
# <class 'MySQLdb.connections.Connection'>
cursor = conn.cursor()
#cursor.execute("DROP TABLE IF EXISTS qoute")
print(type(cursor))
# <class 'MySQLdb.cursors.Cursor'>
#i=0
#cursor.execute("CREATE TABLE qoute (no INT, name text,price int, date text)")

for data in data_list:
    cursor.execute("INSERT INTO qoute VALUES (%s,%s, %s, %s)", data)

conn.commit()
# 연결종료하기
conn.close()
# Out:
# <class 'MySQLdb.connections.Connection'>
# <class 'MySQLdb.cursors.Cursor'>

# %%
#
